# %% [markdown]
# ###  The World Happiness Report

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pylab import rcParams
rcParams['figure.figsize'] = 11,5

# %% [markdown]
# #### Rename
# - Country: Country or region
# - Happiness: Happiness Score
# - Economy: Economy (GDP per capita)
# - Family: Social support
# - Health: Healthy life expectancy
# - Freedom: Freedom to make life choices or
# - Trust: Perceptions of corruption or Government Corruption

# %%
df2015 = pd.read_csv('The_World_Happiness_Report/2015.csv')
df2015['Year'] = 2015
df2015.rename(columns = { 
    df2015.columns[3]: 'Happiness',
    df2015.columns[5]: 'Economy',
    df2015.columns[7]: 'Health',
    df2015.columns[9]: 'Trust',
    df2015.columns[11]: 'Dystopia_Residual',    
}, inplace = True)
df2015['Health'] = round(df2015['Health'] * 100, 1)
df2015 = df2015[['Year', 'Country', 'Happiness', 'Economy', 'Family', 'Health', 'Freedom', 'Trust', 'Generosity']]
df2015.head()
# Out:
#    Year      Country  Happiness  Economy   Family  Health  Freedom    Trust  \
# 0  2015  Switzerland      7.587  1.39651  1.34951    94.1  0.66557  0.41978
# 1  2015      Iceland      7.561  1.30232  1.40223    94.8  0.62877  0.14145
# 2  2015      Denmark      7.527  1.32548  1.36058    87.5  0.64938  0.48357
# 3  2015       Norway      7.522  1.45900  1.33095    88.5  0.66973  0.36503
# 4  2015       Canada      7.427  1.32629  1.32261    90.6  0.63297  0.32957
#
#    Generosity
# 0     0.29678
# 1     0.43630
# 2     0.34139
# 3     0.34699
# 4     0.45811

# %%
df2016 = pd.read_csv('The_World_Happiness_Report/2016.csv')
df2016['Year'] = 2016
df2016.rename(columns = { 
    df2016.columns[3]: 'Happiness',
    df2016.columns[6]: 'Economy',
    df2016.columns[8]: 'Health',
    df2016.columns[10]: 'Trust',
    df2016.columns[12]: 'Dystopia_Residual',    
}, inplace = True)
df2016['Health'] = round(df2016['Health'] * 100, 1)
df2016 = df2016[['Year', 'Country', 'Happiness', 'Economy', 'Family', 'Health', 'Freedom', 'Trust', 'Generosity']]
df2016.head()
# Out:
#    Year      Country  Happiness  Economy   Family  Health  Freedom    Trust  \
# 0  2016      Denmark      7.526  1.44178  1.16374    79.5  0.57941  0.44453
# 1  2016  Switzerland      7.509  1.52733  1.14524    86.3  0.58557  0.41203
# 2  2016      Iceland      7.501  1.42666  1.18326    86.7  0.56624  0.14975
# 3  2016       Norway      7.498  1.57744  1.12690    79.6  0.59609  0.35776
# 4  2016      Finland      7.413  1.40598  1.13464    81.1  0.57104  0.41004
#
#    Generosity
# 0     0.36171
# 1     0.28083
# 2     0.47678
# 3     0.37895
# 4     0.25492

# %%
df2017 = pd.read_csv('The_World_Happiness_Report/2017.csv')
df2017['Year'] = 2017
df2017.rename(columns = { 
    df2017.columns[2]: 'Happiness',
    df2017.columns[5]: 'Economy',
    df2017.columns[7]: 'Health',
    df2017.columns[10]: 'Trust',
    df2017.columns[11]: 'Dystopia_Residual',    
}, inplace = True)
df2017['Health'] = round(df2017['Health'] * 100, 1)
df2017 = df2017[['Year', 'Country', 'Happiness', 'Economy', 'Family', 'Health', 'Freedom', 'Trust', 'Generosity']]
df2017.head()
# Out:
#    Year      Country  Happiness   Economy    Family  Health   Freedom  \
# 0  2017       Norway      7.537  1.616463  1.533524    79.7  0.635423
# 1  2017      Denmark      7.522  1.482383  1.551122    79.3  0.626007
# 2  2017      Iceland      7.504  1.480633  1.610574    83.4  0.627163
# 3  2017  Switzerland      7.494  1.564980  1.516912    85.8  0.620071
# 4  2017      Finland      7.469  1.443572  1.540247    80.9  0.617951
#
#       Trust  Generosity
# 0  0.315964    0.362012
# 1  0.400770    0.355280
# 2  0.153527    0.475540
# 3  0.367007    0.290549
# 4  0.382612    0.245483

# %%
df2018 = pd.read_csv('The_World_Happiness_Report/2018.csv')
df2018['Year'] = 2018
df2018.rename(columns = { 
    df2018.columns[1]: 'Country',
    df2018.columns[2]: 'Happiness',
    df2018.columns[3]: 'Economy',
    df2018.columns[4]: 'Family',
    df2018.columns[5]: 'Health',
    df2018.columns[6]: 'Freedom',
    df2018.columns[8]: 'Trust',    
}, inplace = True)
df2018['Health'] = round(df2018['Health'] * 100, 1)
df2018 = df2018[['Year', 'Country', 'Happiness', 'Economy', 'Family', 'Health', 'Freedom', 'Trust', 'Generosity']]
df2018.head()
# Out:
#    Year      Country  Happiness  Economy  Family  Health  Freedom  Trust  \
# 0  2018      Finland      7.632    1.305   1.592    87.4    0.681  0.393
# 1  2018       Norway      7.594    1.456   1.582    86.1    0.686  0.340
# 2  2018      Denmark      7.555    1.351   1.590    86.8    0.683  0.408
# 3  2018      Iceland      7.495    1.343   1.644    91.4    0.677  0.138
# 4  2018  Switzerland      7.487    1.420   1.549    92.7    0.660  0.357
#
#    Generosity
# 0       0.202
# 1       0.286
# 2       0.284
# 3       0.353
# 4       0.256

# %%
df2019 = pd.read_csv('The_World_Happiness_Report/2019.csv')
df2019['Year'] = 2019
df2019.rename(columns = { 
    df2019.columns[1]: 'Country',
    df2019.columns[2]: 'Happiness',
    df2019.columns[3]: 'Economy',
    df2019.columns[4]: 'Family',
    df2019.columns[5]: 'Health',
    df2019.columns[6]: 'Freedom',
    df2019.columns[8]: 'Trust',    
}, inplace = True)
df2019['Health'] = round(df2019['Health'] * 100, 1)
df2019 = df2019[['Year', 'Country', 'Happiness', 'Economy', 'Family', 'Health', 'Freedom', 'Trust', 'Generosity']]
df2019.head()
# Out:
#    Year      Country  Happiness  Economy  Family  Health  Freedom  Trust  \
# 0  2019      Finland      7.769    1.340   1.587    98.6    0.596  0.393
# 1  2019      Denmark      7.600    1.383   1.573    99.6    0.592  0.410
# 2  2019       Norway      7.554    1.488   1.582   102.8    0.603  0.341
# 3  2019      Iceland      7.494    1.380   1.624   102.6    0.591  0.118
# 4  2019  Netherlands      7.488    1.396   1.522    99.9    0.557  0.298
#
#    Generosity
# 0       0.153
# 1       0.252
# 2       0.271
# 3       0.354
# 4       0.322

# %%
world_happy = pd.concat([df2015, df2016, df2017, df2018, df2019], ignore_index=True)
world_happy['Country'] = world_happy['Country'].replace(['Somaliland region', 'Somaliland Region'], 'Somalia')
world_happy['Country'] = world_happy['Country'].replace(['Trinidad & Tobago'], 'Trinidad and Tobago')
world_happy['Country'] = world_happy['Country'].replace(['Northern Cyprus'], 'North Cyprus')
world_happy['Country'] = world_happy['Country'].replace(['North Macedonia'], 'Macedonia')
world_happy['Country'] = world_happy['Country'].replace(['Hong Kong S.A.R., China'], 'Hong Kong')
world_happy.head()
# Out:
#    Year      Country  Happiness  Economy   Family  Health  Freedom    Trust  \
# 0  2015  Switzerland      7.587  1.39651  1.34951    94.1  0.66557  0.41978
# 1  2015      Iceland      7.561  1.30232  1.40223    94.8  0.62877  0.14145
# 2  2015      Denmark      7.527  1.32548  1.36058    87.5  0.64938  0.48357
# 3  2015       Norway      7.522  1.45900  1.33095    88.5  0.66973  0.36503
# 4  2015       Canada      7.427  1.32629  1.32261    90.6  0.63297  0.32957
#
#    Generosity
# 0     0.29678
# 1     0.43630
# 2     0.34139
# 3     0.34699
# 4     0.45811

# %%
world_happy = pd.concat([df2015, df2016, df2017, df2018, df2019], ignore_index=True)
world_happy['Country'] = world_happy['Country'].replace(['Somaliland Region'], 'Somalia')\
                                               .replace(['Trinidad & Tobago'], 'Trinidad and Tobago')\
                                               .replace(['Northern Cyprus'], 'North Cyprus')\
                                               .replace(['North Macedonia'], 'Macedonia')\
                                               .replace(['Hong Kong S.A.R., China'], 'Hong Kong')\
                                               .replace(['Taiwan Province of China'], 'Taiwan')
world_happy
# Out:
#      Year                   Country  Happiness  Economy   Family  Health  \
# 0    2015               Switzerland      7.587  1.39651  1.34951    94.1
# 1    2015                   Iceland      7.561  1.30232  1.40223    94.8
# 2    2015                   Denmark      7.527  1.32548  1.36058    87.5
# 3    2015                    Norway      7.522  1.45900  1.33095    88.5
# 4    2015                    Canada      7.427  1.32629  1.32261    90.6
# ..    ...                       ...        ...      ...      ...     ...
# 777  2019                    Rwanda      3.334  0.35900  0.71100    61.4
# 778  2019                  Tanzania      3.231  0.47600  0.88500    49.9
# 779  2019               Afghanistan      3.203  0.35000  0.51700    36.1
# 780  2019  Central African Republic      3.083  0.02600  0.00000    10.5
# 781  2019               South Sudan      2.853  0.30600  0.57500    29.5
#
#      Freedom    Trust  Generosity
# 0    0.66557  0.41978     0.29678
# ...

# %%
def counts(country):
    country_counts = {}
    for c in world_happy['Country']:
        if c not in country_counts:
            country_counts[c] = 1
        else:
            country_counts[c] += 1
    
    for k, v in country_counts.items():
        if v == 5:
            return 'five'
        else:
            return v
world_happy['counts'] = world_happy['Country'].apply(counts)

# %%
world_happy['counts'].unique()
# Out:
# array(['five'], dtype=object)

# %%
world_happy
# Out:
#      Year                   Country  Happiness  Economy   Family  Health  \
# 0    2015               Switzerland      7.587  1.39651  1.34951    94.1
# 1    2015                   Iceland      7.561  1.30232  1.40223    94.8
# 2    2015                   Denmark      7.527  1.32548  1.36058    87.5
# 3    2015                    Norway      7.522  1.45900  1.33095    88.5
# 4    2015                    Canada      7.427  1.32629  1.32261    90.6
# ..    ...                       ...        ...      ...      ...     ...
# 777  2019                    Rwanda      3.334  0.35900  0.71100    61.4
# 778  2019                  Tanzania      3.231  0.47600  0.88500    49.9
# 779  2019               Afghanistan      3.203  0.35000  0.51700    36.1
# 780  2019  Central African Republic      3.083  0.02600  0.00000    10.5
# 781  2019               South Sudan      2.853  0.30600  0.57500    29.5
#
#      Freedom    Trust  Generosity counts
# 0    0.66557  0.41978     0.29678   five
# ...

# %%
world_happy['counts'].unique()
# Out:
# array(['five'], dtype=object)

# %%
world_happy.head(50)
# Out:
#     Year               Country  Happiness  Economy   Family  Health  Freedom  \
# 0   2015           Switzerland      7.587  1.39651  1.34951    94.1  0.66557
# 1   2015               Iceland      7.561  1.30232  1.40223    94.8  0.62877
# 2   2015               Denmark      7.527  1.32548  1.36058    87.5  0.64938
# 3   2015                Norway      7.522  1.45900  1.33095    88.5  0.66973
# 4   2015                Canada      7.427  1.32629  1.32261    90.6  0.63297
# 5   2015               Finland      7.406  1.29025  1.31826    88.9  0.64169
# 6   2015           Netherlands      7.378  1.32944  1.28017    89.3  0.61576
# 7   2015                Sweden      7.364  1.33171  1.28907    91.1  0.65980
# 8   2015           New Zealand      7.286  1.25018  1.31967    90.8  0.63938
# 9   2015             Australia      7.284  1.33358  1.30923    93.2  0.65124
# 10  2015                Israel      7.278  1.22857  1.22393    91.4  0.41319
# ...

# %%
#world_happy['counts'] = world_happy.counts.astype('str')

# %%
# Out:
# array([5], dtype=int64)

# %%
for k, v in country_counts.items():
    if v == 5:
        print('five')
    else:
        print (v)

# %%
country_counts = {}
for c in world_happy['Country']:
    if c not in country_counts:
        country_counts[c] = 1
    else:
        country_counts[c] += 1
        
        
country_counts
# Out:
# {'Switzerland': 5,
#  'Iceland': 5,
#  'Denmark': 5,
#  'Norway': 5,
#  'Canada': 5,
#  'Finland': 5,
#  'Netherlands': 5,
#  'Sweden': 5,
#  'New Zealand': 5,
#  'Australia': 5,
#  'Israel': 5,
#  'Costa Rica': 5,
#  'Austria': 5,
#  'Mexico': 5,
#  'United States': 5,
#  'Brazil': 5,
#  'Luxembourg': 5,
#  'Ireland': 5,
#  'Belgium': 5,
#  'United Arab Emirates': 5,
#  'United Kingdom': 5,
#  'Oman': 1,
#  'Venezuela': 5,
#  'Singapore': 5,
#  'Panama': 5,
#  'Germany': 5,
#  'Chile': 5,
#  'Qatar': 5,
#  'France': 5,
#  'Argentina': 5,
#  'Czech Republic': 5,
#  'Uruguay': 5,
#  'Colombia': 5,
#  'Thailand': 5,
#  'Saudi Arabia': 5,
#  'Spain': 5,
#  'Malta': 5,
#  'Taiwan': 5,
#  'Kuwait': 5,
#  'Suriname': 2,
#  'Trinidad and Tobago': 5,
#  'El Salvador': 5,
#  'Guatemala': 5,
#  'Uzbekistan': 5,
#  'Slovakia': 5,
#  'Japan': 5,
#  'South Korea': 5,
#  'Ecuador': 5,
#  'Bahrain': 5,
#  'Italy': 5,
#  'Bolivia': 5,
#  'Moldova': 5,
#  'Paraguay': 5,
#  'Kazakhstan': 5,
# ...

# %%
for k, v in country_counts.items():
    if v == 5:
        print('five')
    else:
        print(v)
# Out:
# five
# five
# five
# five
# five
# five
# five
# five
# five
# five
# five
# five
# five
# five
# five
# five
# five
# five
# five
# five
# five
# 1
# five
# five
# five
# five
# five
# five
# five
# five
# five
# five
# five
# five
# five
# five
# five
# five
# five
# 2
# five
# five
# five
# five
# five
# five
# five
# five
# five
# five
# five
# five
# five
# five
# five
# five
# five
# five
# five
# five
# five
# five
# five
# five
# five
# five
# five
# five
# five
# five
# five
# five
# five
# five
# five
# five
# five
# five
# five
# five
# five
# five
# five
# five
# five
# five
# five
# five
# five
# five
# 1
# five
# five
# 4
# five
# five
# 4
# five
# 4
# five
# 2
# five
# five
# five
# five
# five
# five
# five
# five
# five
# five
# five
# five
# five
# five
# five
# five
# 4
# five
# five
# five
# five
# five
# five
# five
# 1
# five
# five
# five
# five
# five
# five
# five
# five
# five
# five
# 4
# five
# five
# 3
# five
# five
# five
# five
# five
# five
# five
# 4
# ...

# %%
# добавим уровень з/п
for person, info in staff_dict.items():
#     print(person)
    if info['salary'] > 1000:
        info['status'] = 'above average'
    else:
        info['status'] = 'below average'
      #print(f"{person}'s salary: {info['salary']} ({status})")

staff_dict

# %%
def counts(country):
    country_counts = {}
    for c in world_happy['Country']:
        if c not in country_counts:
            country_counts[c] = 1
        else:
            country_counts[c] += 1

    #c = 0
    for k, v in country_counts.items():
        if v == 5:
            return '5'
            #c+=1
        else:
            return v
world_happy['counts'] = world_happy['Country'].apply(counts)
world_happy['counts'] = world_happy.counts.astype('str')

# %%
world_happy['counts'].unique()
# Out:
# array(['5'], dtype=object)

# %%
weight_counts = {}
for w in df['Weight'].round():
    if w not in weight_counts:
        weight_counts[w] = 1
    else:
        weight_counts[w] += 1

# Проходимся по словарю и ищем максимальное количество повторений
# Алгоритм поиска максимума
maxw = 0
mode_weight = None
for k, v in weight_counts.items():
    if maxw < v:
        maxw = v
        mode_weight = k
print('Значение моды:', mode_weight, 'количество встречаемости:', maxw)
# Out:
#   File "<ipython-input-73-1a32f3d93661>", line 10
#     return '5'
#     ^
# SyntaxError: 'return' outside function

# %%
world_happy['counts'].unique()
# Out:
# array(['5'], dtype=object)

# %%
fltr_world_happy = world_happy[ world_happy['counts'] == 'five' ]
fltr_world_happy.tail(50)
# Out:
# Empty DataFrame
# Columns: [Year, Country, Happiness, Economy, Family, Health, Freedom, Trust, Generosity, counts]
# Index: []

# %%
fltr_world_happy.groupby('Country').count().sort_values('Year').head(30)
# Out:
#                           Year  Happiness  Economy  Family  Health  Freedom  \
# Country
# Gambia                       1          1        1       1       1        1
# Puerto Rico                  1          1        1       1       1        1
# Oman                         1          1        1       1       1        1
# Djibouti                     1          1        1       1       1        1
# Somaliland region            1          1        1       1       1        1
# Suriname                     2          2        2       2       2        2
# Swaziland                    2          2        2       2       2        2
# Belize                       3          3        3       3       3        3
# Comoros                      3          3        3       3       3        3
# Sudan                        4          4        4       4       4        4
# South Sudan                  4          4        4       4       4        4
# ...

# %%
gb_world_happy = world_happy.groupby('Country').count()
gb_world_happy
# Out:
#              Year  Happiness  Economy  Family  Health  Freedom  Trust  \
# Country
# Afghanistan     5          5        5       5       5        5      5
# Albania         5          5        5       5       5        5      5
# Algeria         5          5        5       5       5        5      5
# Angola          4          4        4       4       4        4      4
# Argentina       5          5        5       5       5        5      5
# ...           ...        ...      ...     ...     ...      ...    ...
# Venezuela       5          5        5       5       5        5      5
# Vietnam         5          5        5       5       5        5      5
# Yemen           5          5        5       5       5        5      5
# Zambia          5          5        5       5       5        5      5
# Zimbabwe        5          5        5       5       5        5      5
#
#              Generosity  counts
# Country
# Afghanistan           5       5
# Albania               5       5
# ...

# %%
world_happy['counts'].value_counts()
# Out:
# 5    782
# Name: counts, dtype: int64

# %%
type('counts')
# Out:
# str

# %%
fltr_world_happy = world_happy[ world_happy['counts'] == 5 ]
fltr_world_happy
# Out:
# Empty DataFrame
# Columns: [Year, Country, Happiness, Economy, Family, Health, Freedom, Trust, Generosity, counts]
# Index: []

# %%
fltr_world_happy.loc[world_happy.count.str.contains('5')]
world_happy
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-95c13d516db6> in <module>
# ----> 1 fltr_world_happy.loc[world_happy.count.str.contains('5')]
#       2 world_happy
#
# AttributeError: 'function' object has no attribute 'str'

# %%
world_happy.groupby('Country').count().sort_values('Year').head(30)
# Out:
#                           Year  Happiness  Economy  Family  Health  Freedom  \
# Country
# Gambia                       1          1        1       1       1        1
# Puerto Rico                  1          1        1       1       1        1
# Oman                         1          1        1       1       1        1
# Djibouti                     1          1        1       1       1        1
# Somaliland region            1          1        1       1       1        1
# Suriname                     2          2        2       2       2        2
# Swaziland                    2          2        2       2       2        2
# Belize                       3          3        3       3       3        3
# Comoros                      3          3        3       3       3        3
# Sudan                        4          4        4       4       4        4
# South Sudan                  4          4        4       4       4        4
# ...

# %%
filtered_world_happy = world_happy[ world_happy['count'] > 4 ]
filtered_world_happy
# Out:
#      Year                   Country  Happiness  Economy   Family  Health  \
# 0    2015               Switzerland      7.587  1.39651  1.34951    94.1
# 1    2015                   Iceland      7.561  1.30232  1.40223    94.8
# 2    2015                   Denmark      7.527  1.32548  1.36058    87.5
# 3    2015                    Norway      7.522  1.45900  1.33095    88.5
# 4    2015                    Canada      7.427  1.32629  1.32261    90.6
# ..    ...                       ...        ...      ...      ...     ...
# 777  2019                    Rwanda      3.334  0.35900  0.71100    61.4
# 778  2019                  Tanzania      3.231  0.47600  0.88500    49.9
# 779  2019               Afghanistan      3.203  0.35000  0.51700    36.1
# 780  2019  Central African Republic      3.083  0.02600  0.00000    10.5
# 781  2019               South Sudan      2.853  0.30600  0.57500    29.5
#
#      Freedom    Trust  Generosity  count
# 0    0.66557  0.41978     0.29678      5
# ...

# %%
world_happy = world_happy.loc[world_happy['count'] == 5]
world_happy
# Out:
#      Year                   Country  Happiness  Economy   Family  Health  \
# 0    2015               Switzerland      7.587  1.39651  1.34951    94.1
# 1    2015                   Iceland      7.561  1.30232  1.40223    94.8
# 2    2015                   Denmark      7.527  1.32548  1.36058    87.5
# 3    2015                    Norway      7.522  1.45900  1.33095    88.5
# 4    2015                    Canada      7.427  1.32629  1.32261    90.6
# ..    ...                       ...        ...      ...      ...     ...
# 777  2019                    Rwanda      3.334  0.35900  0.71100    61.4
# 778  2019                  Tanzania      3.231  0.47600  0.88500    49.9
# 779  2019               Afghanistan      3.203  0.35000  0.51700    36.1
# 780  2019  Central African Republic      3.083  0.02600  0.00000    10.5
# 781  2019               South Sudan      2.853  0.30600  0.57500    29.5
#
#      Freedom    Trust  Generosity  count
# 0    0.66557  0.41978     0.29678      5
# ...

# %%
filtered_world_happy.groupby('Country').count().sort_values('Year').head(30)
# Out:
#                           Year  Happiness  Economy  Family  Health  Freedom  \
# Country
# Gambia                       1          1        1       1       1        1
# Puerto Rico                  1          1        1       1       1        1
# Oman                         1          1        1       1       1        1
# Djibouti                     1          1        1       1       1        1
# Somaliland region            1          1        1       1       1        1
# Suriname                     2          2        2       2       2        2
# Swaziland                    2          2        2       2       2        2
# Belize                       3          3        3       3       3        3
# Comoros                      3          3        3       3       3        3
# Sudan                        4          4        4       4       4        4
# South Sudan                  4          4        4       4       4        4
# ...

# %%
world_happy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 782 entries, 0 to 781
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Year        782 non-null    int64
#  1   Country     782 non-null    object
#  2   Happiness   782 non-null    float64
#  3   Economy     782 non-null    float64
#  4   Family      782 non-null    float64
#  5   Health      782 non-null    float64
#  6   Freedom     782 non-null    float64
#  7   Trust       781 non-null    float64
#  8   Generosity  782 non-null    float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 55.1+ KB

# %%
level = world_happy['Country'].count()
level
# Out:
# 782

# %%
x = world_happy['Country'].value_counts() == 5
#world_happy.loc[world_happy['Country'].value_counts() == 5]
x == True
# Out:
# Guinea                  True
# Ecuador                 True
# Tunisia                 True
# Congo (Brazzaville)     True
# Paraguay                True
#                        ...
# Oman                   False
# Puerto Rico            False
# Gambia                 False
# Djibouti               False
# Somaliland region      False
# Name: Country, Length: 164, dtype: bool

# %%
world_happy['Country'] = world_happy.count.apply(lambda x: 2 if x == 9 else x)
# Out:
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# <ipython-input-162-79f54f88445c> in <module>
# ----> 1 world_happy.loc[world_happy['Country'].value_counts() > 4]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     877
#     878             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 879             return self._getitem_axis(maybe_callable, axis=axis)
#     880
#     881     def _is_scalar_access(self, key: Tuple):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1088             return self._get_slice_axis(key, axis=axis)
#    1089         elif com.is_bool_indexer(key):
# -> 1090             return self._getbool_axis(key, axis=axis)
#    1091         elif is_list_like_indexer(key):
#    1092
#
# ...

# %%
world_happy.

# %%
world_happy.groupby('Country').count().sort_values('Year').del().count()<5
# Out:
#   File "<ipython-input-167-d463eea8df72>", line 1
#     world_happy.groupby('Country').count().sort_values('Year').del().count()<5
#                                                                ^
# SyntaxError: invalid syntax

# %%
whs = world_happy.sort_values('Country').head()
whs
# Out:
#      Year      Country  Happiness   Economy    Family  Health  Freedom  \
# 311  2016  Afghanistan      3.360  0.382270  0.110370    17.3  0.16430
# 152  2015  Afghanistan      3.575  0.319820  0.302850    30.3  0.23414
# 614  2018  Afghanistan      3.632  0.332000  0.537000    25.5  0.08500
# 779  2019  Afghanistan      3.203  0.350000  0.517000    36.1  0.00000
# 455  2017  Afghanistan      3.794  0.401477  0.581543    18.1  0.10618
#
#         Trust  Generosity
# 311  0.071120    0.312680
# 152  0.097190    0.365100
# 614  0.036000    0.191000
# 779  0.025000    0.158000
# 455  0.061158    0.311871

# %%
world_happy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 782 entries, 0 to 781
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Year        782 non-null    int64
#  1   Country     782 non-null    object
#  2   Happiness   782 non-null    float64
#  3   Economy     782 non-null    float64
#  4   Family      782 non-null    float64
#  5   Health      782 non-null    float64
#  6   Freedom     782 non-null    float64
#  7   Trust       781 non-null    float64
#  8   Generosity  782 non-null    float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 55.1+ KB

# %%
wh = world_happy.groupby('Year').sum()[['Happiness']].head()
wh
# Out:
#       Happiness
# Year
# 2015    849.366
# 2016    845.003
# 2017    829.873
# 2018    838.643
# 2019    843.507

# %%
wh.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5 entries, 2015 to 2019
# Data columns (total 1 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Happiness  5 non-null      float64
# dtypes: float64(1)
# memory usage: 80.0 bytes

# %%
plt.plot(wh.index, wh['Happiness'])
plt.title('Динамика уровня счастья в мире за период 2015-2019г.г.')
plt.xlabel('Год')
plt.ylabel('Уровень счастья')
# Out:
# Text(0, 0.5, 'Уровень счастья')

# %%
three_country = world_happy[ (world_happy['Country'] == 'Russia') | (world_happy['Country'] == 'United States') |\
                             (world_happy['Country'] == 'China') ]
three_country_gb = three_country[ ['Year', 'Country', 'Happiness', 'Economy', 'Family', 'Health', 'Freedom', 'Trust'] ].groupby(['Country', 'Year']).sum()
three_country_gb
# Out:
#                     Happiness   Economy    Family  Health   Freedom     Trust
# Country       Year
# China         2015      5.140  0.890120  0.946750    81.7  0.516970  0.027810
#               2016      5.245  1.027800  0.793810    73.6  0.440120  0.027450
#               2017      5.273  1.081166  1.160837    74.1  0.472788  0.022794
#               2018      5.246  0.989000  1.142000    79.9  0.597000  0.103000
#               2019      5.191  1.029000  1.125000    89.3  0.521000  0.100000
# Russia        2015      5.716  1.137640  1.236170    66.9  0.366790  0.030050
#               2016      5.856  1.232280  1.052610    59.0  0.326820  0.035860
#               2017      5.963  1.281778  1.469282    54.7  0.373783  0.032963
#               2018      5.810  1.151000  1.479000    59.9  0.399000  0.025000
#               2019      5.648  1.183000  1.452000    72.6  0.334000  0.031000
# United States 2015      7.119  1.394510  1.247110    86.2  0.546040  0.158900
# ...

# %%
three_country_gb.drop('Economy', axis=1).plot(kind='area',
                             title='Динамика продаж видеоигр', 
                             xlabel='Год', 
#                                 stacked=False,
                             ylabel='Продажи, млн.')
# Out:
# <AxesSubplot:title={'center':'Динамика продаж видеоигр'}, xlabel='Год', ylabel='Продажи, млн.'>

# %%
tc_Health = three_country[ ['Country', 'Health'] ].groupby('Country').sum()

# %%
tc_Health.loc[['China', 'Russia', 'United States']].plot(kind='bar', 
                                                    title='Happiness by Country',
                                                    xlabel='Country',
                                                    ylabel='Happiness')
# Out:
# <AxesSubplot:title={'center':'Happiness by Country'}, xlabel='Country', ylabel='Happiness'>

# %%
world_happy[ world_happy['Country'].str.contains('un', case=False) ]['Country'].unique()
# Out:
# array(['United States', 'United Arab Emirates', 'United Kingdom',
#        'Hungary', 'Tunisia', 'Burundi'], dtype=object)

# %%
five_country = world_happy[ (world_happy['Country'] == 'Russia') | (world_happy['Country'] == 'United Kingdom') | \
                            (world_happy['Country'] == 'United States') | (world_happy['Country'] == 'Germany') | \
                            (world_happy['Country'] == 'China') ]
five_country_gb = five_country[ ['Year', 'Country', 'Happiness', 'Economy', 'Family', 'Health', 'Freedom', 'Trust'] ].groupby(['Country', 'Year']).sum()
five_country_gb
# Out:
#                      Happiness   Economy    Family  Health   Freedom     Trust
# Country        Year
# China          2015      5.140  0.890120  0.946750    81.7  0.516970  0.027810
#                2016      5.245  1.027800  0.793810    73.6  0.440120  0.027450
#                2017      5.273  1.081166  1.160837    74.1  0.472788  0.022794
#                2018      5.246  0.989000  1.142000    79.9  0.597000  0.103000
#                2019      5.191  1.029000  1.125000    89.3  0.521000  0.100000
# Germany        2015      6.750  1.327920  1.299370    89.2  0.614770  0.218430
#                2016      6.994  1.447870  1.097740    81.5  0.534660  0.285510
#                2017      6.951  1.487923  1.472520    79.9  0.562511  0.276732
#                2018      6.965  1.340000  1.474000    86.1  0.586000  0.280000
#                2019      6.985  1.373000  1.454000    98.7  0.495000  0.265000
# Russia         2015      5.716  1.137640  1.236170    66.9  0.366790  0.030050
# ...

# %%
fc_Happiness = five_country[ ['Country', 'Happiness'] ].groupby('Country').sum()
fc_Economy = five_country[ ['Country', 'Economy'] ].groupby('Country').sum()
fc_Family = five_country[ ['Country', 'Family'] ].groupby('Country').sum()
fc_Health = five_country[ ['Country', 'Health'] ].groupby('Country').sum()
fc_Freedom = five_country[ ['Country', 'Freedom'] ].groupby('Country').sum()
fc_Trust = five_country[ ['Country', 'Trust'] ].groupby('Country').sum()

fc_Happiness
# Out:
#                 Happiness
# Country
# China              26.095
# Germany            34.645
# Russia             28.993
# United Kingdom     34.550
# United States      34.994

# %%
fc_Happiness.loc[['China', 'Germany', 'Russia', 'United Kingdom', 'United States']].plot(kind='bar', 
                   title='Happiness by Country',
                   xlabel='Country',
                   ylabel='Happiness')
# Out:
# <AxesSubplot:title={'center':'Happiness by Country'}, xlabel='Country', ylabel='Happiness'>

# %%
fc_Economy.loc[['China', 'Germany', 'Russia', 'United Kingdom', 'United States']].plot(kind='bar', 
                   title='Happiness by Country',
                   xlabel='Country',
                   ylabel='Happiness')
# Out:
# <AxesSubplot:title={'center':'Happiness by Country'}, xlabel='Country', ylabel='Happiness'>

# %%
fc_Family.loc[['China', 'Germany', 'Russia', 'United Kingdom', 'United States']].plot(kind='bar', 
                   title='Happiness by Country',
                   xlabel='Country',
                   ylabel='Happiness')
# Out:
# <AxesSubplot:title={'center':'Happiness by Country'}, xlabel='Country', ylabel='Happiness'>

# %%
fc_Health.loc[['China', 'Germany', 'Russia', 'United Kingdom', 'United States']].plot(kind='bar', 
                   title='Happiness by Country',
                   xlabel='Country',
                   ylabel='Happiness')
# Out:
# <AxesSubplot:title={'center':'Happiness by Country'}, xlabel='Country', ylabel='Happiness'>

# %%
fc_Freedom.loc[['China', 'Germany', 'Russia', 'United Kingdom', 'United States']].plot(kind='bar', 
                   title='Happiness by Country',
                   xlabel='Country',
                   ylabel='Happiness')
# Out:
# <AxesSubplot:title={'center':'Happiness by Country'}, xlabel='Country', ylabel='Happiness'>

# %%
fc_Trust.loc[['China', 'Germany', 'Russia', 'United Kingdom', 'United States']].plot(kind='bar', 
                   title='Happiness by Country',
                   xlabel='Country',
                   ylabel='Happiness')
# Out:
# <AxesSubplot:title={'center':'Happiness by Country'}, xlabel='Country', ylabel='Happiness'>

# %%
world_happy[['Family']].plot(kind='box',
                   title='User Score distribution', grid=True)
# Out:
# <AxesSubplot:title={'center':'User Score distribution'}>

# %%
world_happy[['Trust']].plot(kind='box',
                   title='User Score distribution', grid=True)
# Out:
# <AxesSubplot:title={'center':'User Score distribution'}>

# %%
world_happy[['Economy']].plot(kind='box',
                   title='User Score distribution', grid=True)
# Out:
# <AxesSubplot:title={'center':'User Score distribution'}>

# %%
world_happy[['Family']].plot(kind='box',
                   title='User Score distribution', grid=True)
# Out:
# <AxesSubplot:title={'center':'User Score distribution'}>

# %%
world_happy[['Health']].plot(kind='box',
                   title='User Score distribution', grid=True)
# Out:
# <AxesSubplot:title={'center':'User Score distribution'}>

# %%
games_by_platforms.loc[['PC', 'X360', 'PS3', 'PS4', 'XOne']].plot(kind='bar', 
                                                                  title='Platforms by Games',
                                                                  xlabel='Platforms',
                                                                  ylabel='Games quantity')

# %%
five_country.drop('Year', axis=1).plot(kind='bar',
                             title='Динамика уровня счастья', 
                             xlabel='Год', 
#                                 stacked=False,
                             ylabel='Уровень счастья')
# Out:
# <AxesSubplot:title={'center':'Динамика уровня счастья'}, xlabel='Год', ylabel='Уровень счастья'>

# %%
five_country.plot(title='Динамика продаж видеоигр', 
                             xlabel='Год', 
                             ylabel='Продажи, млн.')
plt.text(2007, 680, 'Почему отсюда начался спад?')  
plt.legend(loc='upper left')

# %%
wh = world_happy.groupby('Happiness')
wh.max().head()
# Out:
#            Year                   Country   Economy    Family  Health  \
# Happiness
# 2.693      2017  Central African Republic  0.000000  0.000000     1.9
# 2.839      2015                      Togo  0.208680  0.139950    28.4
# 2.853      2019               South Sudan  0.306000  0.575000    29.5
# 2.905      2017                   Burundi  0.091623  0.629794    15.2
# 2.905      2018                   Burundi  0.091000  0.627000    22.4
#
#             Freedom     Trust  Generosity
# Happiness
# 2.693      0.270842  0.056565    0.280876
# 2.839      0.364530  0.107310    0.166810
# 2.853      0.010000  0.091000    0.202000
# 2.905      0.059901  0.084148    0.204435
# 2.905      0.118500  0.100620    0.202900

# %%
world_happy.groupby('Country').count()['Happiness'].max()
# Out:
# 5

# %%
world_happy.groupby('Country').agg(['min', 'max'])['Happiness'].head()
# Out:
#                min    max
# Country
# Afghanistan  3.203  3.794
# Albania      4.586  4.959
# Algeria      5.211  6.355
# Angola       3.795  4.033
# Argentina    6.086  6.650

# %%
world_happy.groupby('Country').agg(['sum'])['Happiness'].sort_values('sum', ascending=False).head()
# Out:
#                 sum
# Country
# Denmark      37.730
# Norway       37.705
# Finland      37.689
# Switzerland  37.557
# Iceland      37.555

# %%
world_happy.groupby('Country').agg(['sum'])['Happiness'].sort_values('sum', ascending=False).tail()
# Out:
#                      sum
# Country
# North Macedonia    5.274
# Somaliland region  5.057
# Somaliland Region  5.057
# Gambia             4.516
# Djibouti           4.369

# %%
world_happy.groupby('Country').count().sort_values('Year').head(30)
# Out:
#                           Year  Happiness  Economy  Family  Health  Freedom  \
# Country
# Puerto Rico                  1          1        1       1       1        1
# Djibouti                     1          1        1       1       1        1
# Hong Kong S.A.R., China      1          1        1       1       1        1
# Oman                         1          1        1       1       1        1
# North Macedonia              1          1        1       1       1        1
# Taiwan Province of China     1          1        1       1       1        1
# Gambia                       1          1        1       1       1        1
# Suriname                     2          2        2       2       2        2
# Swaziland                    2          2        2       2       2        2
# Belize                       3          3        3       3       3        3
# Comoros                      3          3        3       3       3        3
# ...

# %%
world_happy.groupby('Country').agg(['sum'])['Happiness'].sort_values(world_happy['Country'], 'sum', ascending=False).tail()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _get_axis_number(cls, axis)
#     367         try:
# --> 368             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     369         except KeyError:
#
# KeyError: 'sum'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-59-103d9e567946> in <module>
# ----> 1 world_happy.groupby('Country').agg(['sum'])['Happiness'].sort_values(world_happy['Country'], 'sum', ascending=False).tail()
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    5267     ):
#    5268         inplace = validate_bool_kwarg(inplace, "inplace")
# -> 5269         axis = self._get_axis_number(axis)
# ...

# %%
df2019[ df2019['Country'].str.contains('un', case=False) ]['Country'].unique()
# Out:
# array(['United Kingdom', 'United States', 'United Arab Emirates',
#        'Hungary', 'Tunisia', 'Burundi'], dtype=object)

# %%
whf = world_happy.sort_values(by=['Country'], ascending=True)
whf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 782 entries, 311 to 452
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Year        782 non-null    int64
#  1   Country     782 non-null    object
#  2   Happiness   782 non-null    float64
#  3   Economy     782 non-null    float64
#  4   Family      782 non-null    float64
#  5   Health      782 non-null    float64
#  6   Freedom     782 non-null    float64
#  7   Trust       781 non-null    float64
#  8   Generosity  782 non-null    float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 61.1+ KB

# %%
world_happy['Dystopia_Residual'].fillna(world_happy.groupby(['Economy'])['Dystopia_Residual'].transform('median'), inplace=True)
world_happy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 782 entries, 0 to 781
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Year               782 non-null    int64
#  1   Country            782 non-null    object
#  2   Happiness          782 non-null    float64
#  3   Economy            782 non-null    float64
#  4   Family             782 non-null    float64
#  5   Health             782 non-null    float64
#  6   Freedom            782 non-null    float64
#  7   Trust              781 non-null    float64
#  8   Generosity         782 non-null    float64
#  9   Dystopia_Residual  472 non-null    float64
# dtypes: float64(8), int64(1), object(1)
# memory usage: 61.2+ KB

# %%
df2019 = pd.read_csv('The_World_Happiness_Report/2019.csv')
df2019['year'] = 2019
df2017.rename(columns = { 
    df2017.columns[1]: 'Country',
    df2017.columns[7]: 'Healthy life expectancy',
    df2017.columns[8]: 'Freedom to make life choices',
    df2017.columns[10]: 'Perceptions of corruption'
}, inplace = True)
df2019.info()
df2019['Score'].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 10 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  156 non-null    int64
#  1   Country or region             156 non-null    object
#  2   Score                         156 non-null    float64
#  3   GDP per capita                156 non-null    float64
#  4   Social support                156 non-null    float64
#  5   Healthy life expectancy       156 non-null    float64
#  6   Freedom to make life choices  156 non-null    float64
#  7   Generosity                    156 non-null    float64
#  8   Perceptions of corruption     156 non-null    float64
#  9   year                          156 non-null    int64
# dtypes: float64(7), int64(2), object(1)
# memory usage: 12.3+ KB
# 5.208    2
# 5.467    1
# 7.139    1
# 4.944    1
# 4.350    1
#         ..
# 6.028    1
# ...

# %%
Country, Happiness Rank, Happiness Score, Economy (GDP per Capita), Family, Health (Life Expectancy), Freedom,\
Trust (Government Corruption), Generosity, Dystopia Residual, year

2015: Standard Error
2016: Lower Confidence Interval, Upper Confidence Interval,
2017: RENAME: Economy..GDP.per.Capita. & Health..Life.Expectancy. & Trust..Government.Corruption. & Dystopia.Residual
      Whisker.high, Whisker.low, 
2018: RENAME: Country or region & Score & GDP per capita & Healthy life & Freedom to make life choices expectancy\
      Perceptions of corruption 
      Overall rank, Social support,
2019: RENAME: Country or region & Score & GDP per capita & Healthy life expectancy & Freedom to make life choices &
        Perceptions of corruption
      Overall rank, Social support,
    
    
Country

# %%
df2018 = pd.read_csv('The_World_Happiness_Report/2018.csv')
df2018['year'] = 2018
df2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 10 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  156 non-null    int64
#  1   Country or region             156 non-null    object
#  2   Score                         156 non-null    float64
#  3   GDP per capita                156 non-null    float64
#  4   Social support                156 non-null    float64
#  5   Healthy life expectancy       156 non-null    float64
#  6   Freedom to make life choices  156 non-null    float64
#  7   Generosity                    156 non-null    float64
#  8   Perceptions of corruption     155 non-null    float64
#  9   year                          156 non-null    int64
# dtypes: float64(7), int64(2), object(1)
# memory usage: 12.3+ KB

# %%
df2017 = pd.read_csv('The_World_Happiness_Report/2017.csv')
df2017['year'] = 2017
df2017.rename(columns = { 
    df2017.columns[5]: 'Economy (GDP per Capita)',
    df2017.columns[7]: 'Healthy life expectancy)',
    df2017.columns[8]: 'Freedom to make life choices)',
    df2017.columns[10]: 'Perceptions of corruption)'
}, inplace = True)            
              
df2017.head()
# Out:
#        Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 0       Norway               1            7.537      7.594445     7.479556
# 1      Denmark               2            7.522      7.581728     7.462272
# 2      Iceland               3            7.504      7.622030     7.385970
# 3  Switzerland               4            7.494      7.561772     7.426227
# 4      Finland               5            7.469      7.527542     7.410458
#
#    Economy (GDP per Capita)    Family  Healthy life expectancy)  \
# 0                  1.616463  1.533524                  0.796667
# 1                  1.482383  1.551122                  0.792566
# 2                  1.480633  1.610574                  0.833552
# 3                  1.564980  1.516912                  0.858131
# 4                  1.443572  1.540247                  0.809158
#
#    Freedom to make life choices)  Generosity  Perceptions of corruption)  \
# ...

# %%
df2017['Happiness.Rank'].value_counts()
# Out:
# 155    1
# 49     1
# 56     1
# 55     1
# 54     1
#       ..
# 103    1
# 102    1
# 101    1
# 100    1
# 1      1
# Name: Happiness.Rank, Length: 155, dtype: int64

# %%
df2016 = pd.read_csv('The_World_Happiness_Report/2016.csv')
df2016['year'] = 2016
df2016.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 14 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        157 non-null    object
#  1   Region                         157 non-null    object
#  2   Happiness Rank                 157 non-null    int64
#  3   Happiness Score                157 non-null    float64
#  4   Lower Confidence Interval      157 non-null    float64
#  5   Upper Confidence Interval      157 non-null    float64
#  6   Economy (GDP per Capita)       157 non-null    float64
#  7   Family                         157 non-null    float64
#  8   Health (Life Expectancy)       157 non-null    float64
#  9   Freedom                        157 non-null    float64
#  10  Trust (Government Corruption)  157 non-null    float64
#  11  Generosity                     157 non-null    float64
# ...

# %%
Country, Region, Happiness Rank, Happiness Score, Economy (GDP per Capita), Family, Health (Life Expectancy), Freedom,\
Trust (Government Corruption), Generosity, Dystopia Residual, year
2015: Standard Error
2016: Lower Confidence Interval, Upper Confidence Interval,

# %%
df2015 = pd.read_csv('The_World_Happiness_Report/2015.csv')
df2015['year'] = 2015
df2015.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 13 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
df_full = pd.concat([df2015, df2016, df2017, df2018, df2019], ignore_index=True)
df_full
# Out:
#          Country          Region  Happiness Rank  Happiness Score  \
# 0    Switzerland  Western Europe             1.0            7.587
# 1        Iceland  Western Europe             2.0            7.561
# 2        Denmark  Western Europe             3.0            7.527
# 3         Norway  Western Europe             4.0            7.522
# 4         Canada   North America             5.0            7.427
# ..           ...             ...             ...              ...
# 777          NaN             NaN             NaN              NaN
# 778          NaN             NaN             NaN              NaN
# 779          NaN             NaN             NaN              NaN
# 780          NaN             NaN             NaN              NaN
# 781          NaN             NaN             NaN              NaN
#
#      Standard Error  Economy (GDP per Capita)   Family  \
# 0           0.03411                   1.39651  1.34951
# 1           0.04884                   1.30232  1.40223
# ...

# %%
df_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 780 entries, 0 to 779
# Data columns (total 10 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  780 non-null    int64
#  1   Country or region             780 non-null    object
#  2   Score                         780 non-null    float64
#  3   GDP per capita                780 non-null    float64
#  4   Social support                780 non-null    float64
#  5   Healthy life expectancy       780 non-null    float64
#  6   Freedom to make life choices  780 non-null    float64
#  7   Generosity                    780 non-null    float64
#  8   Perceptions of corruption     776 non-null    float64
#  9   year                          780 non-null    int64
# dtypes: float64(7), int64(2), object(1)
# memory usage: 61.1+ KB

# %%
df2015
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
df2016
# Out:
#          Country                           Region  Happiness Rank  \
# 0        Denmark                   Western Europe               1
# 1    Switzerland                   Western Europe               2
# 2        Iceland                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4        Finland                   Western Europe               5
# ..           ...                              ...             ...
# 152        Benin               Sub-Saharan Africa             153
# 153  Afghanistan                    Southern Asia             154
# 154         Togo               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
#
#      Happiness Score  Lower Confidence Interval  Upper Confidence Interval  \
# 0              7.526                      7.460                      7.592
# ...

# %%
df2017
# Out:
#                       Country  Happiness.Rank  Happiness.Score  Whisker.high  \
# 0                      Norway               1            7.537      7.594445
# 1                     Denmark               2            7.522      7.581728
# 2                     Iceland               3            7.504      7.622030
# 3                 Switzerland               4            7.494      7.561772
# 4                     Finland               5            7.469      7.527542
# ..                        ...             ...              ...           ...
# 150                    Rwanda             151            3.471      3.543030
# 151                     Syria             152            3.462      3.663669
# 152                  Tanzania             153            3.349      3.461430
# 153                   Burundi             154            2.905      3.074690
# 154  Central African Republic             155            2.693      2.864884
#
# ...

# %%
df2018
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.632           1.305
# 1               2                    Norway  7.594           1.456
# 2               3                   Denmark  7.555           1.351
# 3               4                   Iceland  7.495           1.343
# 4               5               Switzerland  7.487           1.420
# ..            ...                       ...    ...             ...
# 151           152                     Yemen  3.355           0.442
# 152           153                  Tanzania  3.303           0.455
# 153           154               South Sudan  3.254           0.337
# 154           155  Central African Republic  3.083           0.024
# 155           156                   Burundi  2.905           0.091
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.592                    0.874                         0.681
# ...

# %%
df2019
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# ...

# %%
# Out:
#       price      brand    model  year   title_status   mileage   color  \
# 0      6300     toyota  cruiser  2008  clean vehicle  274117.0   black
# 1      2899       ford       se  2011  clean vehicle  190552.0  silver
# 2      5350      dodge      mpv  2018  clean vehicle   39590.0  silver
# 3     25000       ford     door  2014  clean vehicle   64146.0    blue
# 4     27700  chevrolet     1500  2018  clean vehicle    6654.0     red
# ...     ...        ...      ...   ...            ...       ...     ...
# 2494   7800     nissan    versa  2019  clean vehicle   23609.0     red
# 2495   9200     nissan    versa  2018  clean vehicle   34553.0  silver
# 2496   9200     nissan    versa  2018  clean vehicle   31594.0  silver
# 2497   9200     nissan    versa  2018  clean vehicle   32557.0   black
# 2498   9200     nissan    versa  2018  clean vehicle   31371.0  silver
#
#            state country
# 0     new jersey     usa
# 1      tennessee     usa
# 2        georgia     usa
# ...
